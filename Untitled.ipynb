# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv("variant1.csv")

# %%
data
# Out:
#                id             date     price  bedrooms  bathrooms
# 0      7129300520  20141013T000000  221900.0         3       1.00  \
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade
# 0             1180      5650     1.0           0     0  ...      7  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
from sklearn.model_selection import train_test_split

X = data.drop(['date'], axis=1)
Y = data['date']

# %%
train_data['date'] = pd.to_numeric(train_data['date'], errors='coerce')

# %%
train_data = pd.get_dummies(train_data, columns=['date'])

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
train_data['date'] = le.fit_transform(train_data['date'])

# %%
from sklearn.model_selection import train_test_split

X = data.drop(['id'], axis=1)
Y = data['id']

# %%
train_data['id'] = pd.to_numeric(train_data['id'], errors='coerce')

# %%
train_data = pd.get_dummies(train_data, columns=['id'])

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
train_data['id'] = le.fit_transform(train_data['id'])

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.4)

# %%
train_data = X_train.join(Y_train)

# %%
train_data
# Out:
#                id  date      price  bedrooms  bathrooms  sqft_living
# 3438   7000100711   NaN  1100000.0  1.386294   1.252763         2200  \
# 5689   4083306345   NaN  1000000.0  1.609438   0.916291         2100
# 1187   6398000171   NaN   545000.0  1.098612   1.098612         2930
# 16173  8582010290   NaN   683000.0  1.386294   1.252763         2300
# 19166  1136100062   NaN   585000.0  1.609438   1.446919         2400
# ...           ...   ...        ...       ...        ...          ...
# 19103   424059052   NaN   400000.0  1.386294   0.693147         1300
# 3509   7550800195   NaN   535000.0  1.609438   0.916291         1580
# 7324   3374500250   NaN   363500.0  1.609438   1.252763         2680
# 650    4338800370   NaN   220000.0  1.386294   0.693147         1000
# 12690  4078300040   NaN   850000.0  1.386294   1.504077         3070
#
#        sqft_lot  floors  waterfront      view  ...  grade  sqft_above
# ...

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<AxesSubplot: title={'center': 'id'}>,
#         <AxesSubplot: title={'center': 'date'}>,
#         <AxesSubplot: title={'center': 'price'}>,
#         <AxesSubplot: title={'center': 'bedrooms'}>,
#         <AxesSubplot: title={'center': 'bathrooms'}>],
#        [<AxesSubplot: title={'center': 'sqft_living'}>,
#         <AxesSubplot: title={'center': 'sqft_lot'}>,
#         <AxesSubplot: title={'center': 'floors'}>,
#         <AxesSubplot: title={'center': 'waterfront'}>,
#         <AxesSubplot: title={'center': 'view'}>],
#        [<AxesSubplot: title={'center': 'condition'}>,
#         <AxesSubplot: title={'center': 'grade'}>,
#         <AxesSubplot: title={'center': 'sqft_above'}>,
#         <AxesSubplot: title={'center': 'sqft_basement'}>,
#         <AxesSubplot: title={'center': 'yr_built'}>],
#        [<AxesSubplot: title={'center': 'yr_renovated'}>,
#         <AxesSubplot: title={'center': 'zipcode'}>,
#         <AxesSubplot: title={'center': 'lat'}>,
# ...

# %%
plt.figure(figsize=(16,8))
sns.heatmap(train_data.corr(), annot=True, cmap="YlGnBu")
# Out:
# <AxesSubplot: >

# %%
train_data['bedrooms'] = np.log(train_data['bedrooms'] +1) 
train_data['floors'] = np.log(train_data['floors'] +1) 
train_data['waterfront'] = np.log(train_data['waterfront'] +1) 
train_data['condition'] = np.log(train_data['condition'] +1) 
train_data['grade'] = np.log(train_data['grade'] +1) 
train_data['sqft_above'] = np.log(train_data['sqft_above'] +1) 
train_data['bathrooms'] = np.log(train_data['bathrooms'] +1) 
train_data['sqft_basement'] = np.log(train_data['sqft_basement'] +1) 
train_data['yr_renovated'] = np.log(train_data['yr_renovated'] +1) 
train_data['long'] = np.log(train_data['long'] +1) 
train_data['lat'] = np.log(train_data['lat'] +1) 
train_data['zipcode'] = np.log(train_data['zipcode'] +1) 
train_data['sqft_living'] = np.log(train_data['sqft_living'] +1)
train_data['sqft_living15'] = np.log(train_data['sqft_living15'] +1) 
train_data['sqft_lot15'] = np.log(train_data['sqft_lot15'] +1) 
train_data['sqft_lot'] = np.log(train_data['sqft_lot'] +1) 
train_data['yr_built'] = np.log(train_data['yr_built'] +1) 
train_data['price'] = np.log(train_data['price'] +1)

# %%
train_data.hist(figsize=(16,8))
# Out:
# array([[<AxesSubplot: title={'center': 'id'}>,
#         <AxesSubplot: title={'center': 'date'}>,
#         <AxesSubplot: title={'center': 'price'}>,
#         <AxesSubplot: title={'center': 'bedrooms'}>,
#         <AxesSubplot: title={'center': 'bathrooms'}>],
#        [<AxesSubplot: title={'center': 'sqft_living'}>,
#         <AxesSubplot: title={'center': 'sqft_lot'}>,
#         <AxesSubplot: title={'center': 'floors'}>,
#         <AxesSubplot: title={'center': 'waterfront'}>,
#         <AxesSubplot: title={'center': 'view'}>],
#        [<AxesSubplot: title={'center': 'condition'}>,
#         <AxesSubplot: title={'center': 'grade'}>,
#         <AxesSubplot: title={'center': 'sqft_above'}>,
#         <AxesSubplot: title={'center': 'sqft_basement'}>,
#         <AxesSubplot: title={'center': 'yr_built'}>],
#        [<AxesSubplot: title={'center': 'yr_renovated'}>,
#         <AxesSubplot: title={'center': 'zipcode'}>,
#         <AxesSubplot: title={'center': 'lat'}>,
# ...

# %%
plt.figure(figsize=(16,8))
sns.scatterplot(x="lat", y="long", data=train_data, hue="grade", palette="coolwarm")
plt.title("Comparison of Year Renovated and Year Built")
plt.xlabel("Latitude")
plt.ylabel("Longitude")

plt.show()

# %%
train_data['bedroom_ratio'] = train_data['bedrooms'] / train_data['floors']

# %%
from sklearn.linear_model import LinearRegression


X_train, Y_train = train_data.drop(['grade'], axis=1), train_data['grade']

reg = LinearRegression()

reg.fit(X_train, Y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[134], line 8
#       4 X_train, Y_train = train_data.drop(['grade'], axis=1), train_data['grade']
#       6 reg = LinearRegression()
# ----> 8 reg.fit(X_train, Y_train)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_base.py:648, in LinearRegression.fit(self, X, y, sample_weight)
#     644 n_jobs_ = self.n_jobs
#     646 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 648 X, y = self._validate_data(
#     649     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     650 )
#     652 sample_weight = _check_sample_weight(
#     653     sample_weight, X, dtype=X.dtype, only_non_negative=True
#     654 )
#     656 X, y, X_offset, y_offset, X_scale = _preprocess_data(
#     657     X,
#     658     y,
#    (...)
# ...

# %%
Linear
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[120], line 1
# ----> 1 LinearRegression()
#
# NameError: name 'LinearRegression' is not defined

# %%
test_data = X_test.join(Y_test)

test_data['bedrooms'] = np.log(test_data['bedrooms'] +1) 
test_data['floors'] = np.log(test_data['floors'] +1) 
test_data['waterfront'] = np.log(test_data['waterfront'] +1) 
test_data['condition'] = np.log(test_data['condition'] +1) 
test_data['grade'] = np.log(test_data['grade'] +1) 
test_data['sqft_above'] = np.log(test_data['sqft_above'] +1) 
test_data['bathrooms'] = np.log(test_data['bathrooms'] +1) 
test_data['sqft_basement'] = np.log(test_data['sqft_basement'] +1) 
test_data['yr_renovated'] = np.log(test_data['yr_renovated'] +1) 
test_data['long'] = np.log(test_data['long'] +1) 
test_data['lat'] = np.log(test_data['lat'] +1) 
test_data['zipcode'] = np.log(test_data['zipcode'] +1) 
test_data['sqft_living'] = np.log(test_data['sqft_living'] +1)
test_data['sqft_living15'] = np.log(test_data['sqft_living15'] +1) 
test_data['sqft_lot15'] = np.log(test_data['sqft_lot15'] +1) 
test_data['sqft_lot'] = np.log(test_data['sqft_lot'] +1) 
test_data['yr_built'] = np.log(test_data['yr_built'] +1) 
test_data['price'] = np.log(test_data['price'] +1) 

test_data = test_data.join(pd.get_dummies(test_data.id)).drop(['id'], axis=1)
test_data = test_data.join(pd.get_dummies(test_data.date)).drop(['date'], axis=1)



test_data['bedroom_ratio'] = test_data['bedrooms'] / test_data['floors']
# Out:
# C:\Users\legion\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
X_test, Y_test = test_data.drop(['price'], axis=1), test_data['price']

# %%
reg.score(X_test, Y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[115], line 1
# ----> 1 reg.score(X_test, Y_test)
#
# NameError: name 'reg' is not defined

# %%
from sklearn.ensemble import RandomForestRegressor

forest = RandomForestRegressor()

forest.fit(X_train, Y_train)

# %%
RandomForestRegressor()

# %%
forest.score(X_test, Y_test)
